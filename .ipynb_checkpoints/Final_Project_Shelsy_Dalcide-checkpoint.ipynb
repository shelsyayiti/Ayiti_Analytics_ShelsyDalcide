# %% [markdown]
# <p>
#  <img src="ayiti_analytics.png" alt="Ayiti Analytics"width=400 />
# </p>

# %% [markdown]
# ##                                       Ayiti Analytics Final Project

# %% [markdown]
# ## **A New Social Life**

# %% [markdown]
# * **By: Shelsy DALCIDE**
#                                                                                                         July 22, 2020

# %% [markdown]
# ## Table of contents
# * [Introduction: Business Problem](#introduction)
# * [Data](#data)
# * [Methodology](#methodology)
# * [Analysis](#analysis)
# * [Results and Discussion](#results)
# * [Conclusion](#conclusion)

# %% [markdown]
# ## **Project Description:** <a name="introduction"></a>
#
# It is not easy for someone to leave his country of origin to go live elsewhere a young man would like in Chicago IL to rebuild his life
# This project will be useful for people wishing to leave their countries to live in Chicago IL.
# He would like to have additional information so quickly regarding districts such as:
# * **The average salary of a person living in Chicago IL**
# * **The price of houses their variations**
# * **The community zone**
# * **The level of security.**
#
# This problem is interesting for him because he will make new experiences, he will have to adapt to this new home which will allow him to learn more about himself. After our Analysis in fact, he will admit his ability to undertake anything, anywhere.
# And he will feel at home in an entirely different place.
# Becoming aware of his possibilities will make him more determined to succeed.
# And discovering different places will help him to think more creatively.

# %% [markdown]
# ## Data Prepocessing <a name="data"></a>
#
# In this cell we take our various data either by internet or by Excel document.

# %% [markdown]
# # Import our library

# %%
#import our library
import pandas as pd
import numpy as np
from geopy.geocoders import Nominatim
import time

import json

import requests
from pandas.io.json import json_normalize
from bs4 import BeautifulSoup
from selenium import webdriver

import matplotlib.cm as cm
import matplotlib.colors as colors
import requests
import seaborn as sns
import matplotlib.pyplot as plt
import re
import seaborn as sns

from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import PolynomialFeatures
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix
from sklearn.pipeline import Pipeline
from math import pi

from sklearn.cluster import KMeans
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize
from geopy.geocoders import Nominatim 
import folium

# %% [markdown]
# # Our First Web Scrapping for the Population of Illinois

# %%
browser = webdriver.Chrome()

# %%
#Breaking down the url in 2 part to be able to insert the page number
url_part_1 = 'http://www.city-data.com/city/Illinois.html'

# %%
browser.get(url_part_1)
soup = BeautifulSoup(browser.page_source,'html.parser')
result = soup.find_all(id= 'cityTAB')

# %%
len(result)
# Out:
# 1

# %%
# with a loop we will have our DataFrame
rows = result[1].find_all('tr')
city_name =[]
population =[]
for row in rows:
    tds =row.find_all('td')
    if len(tds) ==3:        
        city_name.append(tds[1].get_text().strip())
        population.append(tds[2].get_text().strip())
df_population =pd.DataFrame(dict(city_name=city_name,population=population))

# %%
#let's see the dataset of our population with 
df_population

# %%
df_population.isnull().sum()

# %%
#here we save the dataset of our city with population
df_population.to_csv('Data/populationIL.csv',index=False)

# %% [markdown]
# ## Dataset of Population of Illinois saved and load

# %%
#load the dataset of population of illinois
df_population_official = pd.read_csv('Data/populationIL.csv')

# %%
#see the dataset of population of illinois
df_population_official
# Out:
#           city_name population
# 0      Abingdon, IL      3,226
# 1         Adair, IL        210
# 2        Addieville        243
# 3       Addison, IL     37,297
# 4        Albany, IL        883
# ...             ...        ...
# 1198      Xenia, IL        385
# 1199     Yates City        678
# 1200  Yorkville, IL     18,096
# 1201        Zeigler      1,762
# 1202       Zion, IL     24,264
#
# [1203 rows x 2 columns]

# %%
# here we replace Illinois in iL
df_population_official.city_name=df_population_official.city_name.str.replace("Illinois","IL")
df_population_official
# Out:
#           city_name  population
# 0      Abingdon, IL         NaN
# 1         Adair, IL       210.0
# 2        Addieville       243.0
# 3       Addison, IL         NaN
# 4        Albany, IL       883.0
# ...             ...         ...
# 1198      Xenia, IL       385.0
# 1199     Yates City       678.0
# 1200  Yorkville, IL         NaN
# 1201        Zeigler         NaN
# 1202       Zion, IL         NaN
#
# [1203 rows x 2 columns]

# %%
# we can see the first row
df_population_official.iloc[0,:].city_name
# Out:
# 'Abingdon, IL'

# %%
df_population_official.city_name.str.strip()
# Out:
# 0        Abingdon, IL
# 1           Adair, IL
# 2          Addieville
# 3         Addison, IL
# 4          Albany, IL
#             ...
# 1198        Xenia, IL
# 1199       Yates City
# 1200    Yorkville, IL
# 1201          Zeigler
# 1202         Zion, IL
# Name: city_name, Length: 1203, dtype: object

# %%
df_population_official["city_name"]=df_population_official["city_name"].str.strip()

# %%
df_population_official
# Out:
#           city_name  population
# 0      Abingdon, IL         NaN
# 1         Adair, IL       210.0
# 2        Addieville       243.0
# 3       Addison, IL         NaN
# 4        Albany, IL       883.0
# ...             ...         ...
# 1198      Xenia, IL       385.0
# 1199     Yates City       678.0
# 1200  Yorkville, IL         NaN
# 1201        Zeigler         NaN
# 1202       Zion, IL         NaN
#
# [1203 rows x 2 columns]

# %%
df_population_official.describe()
# Out:
#        population
# count  500.000000
# mean   502.166000
# std    220.364215
# min    201.000000
# 25%    309.500000
# 50%    470.500000
# 75%    665.250000
# max    999.000000

# %% [markdown]
# # Our Second Web Scrapping for the salary of people by cities

# %%
#Breaking down the url of our seconde site in 2 part to be able to insert the page number
url_part_2 = 'https://en.wikipedia.org/wiki/List_of_Illinois_locations_by_per_capita_income'

# %%
browser.get(url_part_2)
soup = BeautifulSoup(browser.page_source,'html.parser')
result2 =soup.find_all('ol')

# %%
lis = result2[0].find_all('li')

# %%
city_name,city_income = [],[]
for li in lis:
    print(li.get_text().strip())
    city_name.append(li.get_text().strip().split('–')[0])
    city_income.append(li.get_text().strip().split('–')[-1])
    
df_income = pd.DataFrame(dict(city_name=city_name,city_income=city_income))

# %%
#see the dataset
df_income

# %%
#we save the dataset who's about the wages of people in this city
df_income.to_csv('Data/City_income.csv',index=False)

# %%
df_income_official= pd.read_csv('Data/City_income.csv')

# %%
df_income_official
# Out:
#                    city_name city_income
# 0                  Winnetka      $98,139
# 1                Kenilworth      $97,381
# 2                   Glencoe      $94,900
# 3                 Inverness      $91,623
# 4          Barrington Hills      $91,555
# ...                      ...         ...
# 1309     Brooklyn, Illinois       $7,944
# 1310     Fidelity, Illinois       $7,798
# 1311  Valley City, Illinois       $6,833
# 1312    Kaskaskia, Illinois           $0
# 1313       Ohlman, Illinois           $0
#
# [1314 rows x 2 columns]

# %%
df_income_official.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1314 entries, 0 to 1313
# Data columns (total 2 columns):
# city_name      1314 non-null object
# city_income    1314 non-null object
# dtypes: object(2)
# memory usage: 20.7+ KB

# %% [markdown]
# # Convert the column city_income into float
# * For make Analysis
# * And make some calcul (Chart)

# %%
def convert_to_float(x):
    x= x.replace(',','')
    x=re.findall('[0-9]+', x)
    return float(x[0])

# %%
df_income_official.city_income=df_income_official.city_income.apply(lambda x: convert_to_float(x))

# %%
df_income_official.tail()
# Out:
#                    city_name  city_income
# 1309     Brooklyn, Illinois        7944.0
# 1310     Fidelity, Illinois        7798.0
# 1311  Valley City, Illinois        6833.0
# 1312    Kaskaskia, Illinois           0.0
# 1313       Ohlman, Illinois           0.0

# %%
df_income_official2 = df_income_official[df_income_official.city_income >0]

# %%
df_income_official.isnull().sum()
# Out:
# city_name      0
# city_income    0
# dtype: int64

# %%
df_income_official2
# Out:
#                        city_name  city_income
# 0                      Winnetka       98139.0
# 1                    Kenilworth       97381.0
# 2                       Glencoe       94900.0
# 3                     Inverness       91623.0
# 4              Barrington Hills       91555.0
# ...                          ...          ...
# 1307  Washington Park, Illinois        8495.0
# 1308       Mill Creek, Illinois        8317.0
# 1309         Brooklyn, Illinois        7944.0
# 1310         Fidelity, Illinois        7798.0
# 1311      Valley City, Illinois        6833.0
#
# [1312 rows x 2 columns]

# %% [markdown]
# # Here we just replace all rows who has Illinois in IL in the dataset of the salary (income)
# * For merge our dataset income and the dataaset population
# * For make our Analysis

# %%
#Here we just replace all rows who has Illinois in IL
df_income_official2.city_name=df_income_official2.city_name.str.replace("Illinois","IL")

# %%
df_income_official2.sort_values("city_name",ascending=False)
# Out:
#            city_name  city_income
# 673         Zion, IL      17730.0
# 1129     Zeigler, IL      13781.0
# 178    Yorkville, IL      24514.0
# 635   Yates City, IL      18036.0
# 611         Yale, IL      18199.0
# ...              ...          ...
# 534       Albany, IL      18780.0
# 380      Adeline, IL      20301.0
# 317      Addison, IL      21201.0
# 848   Addieville, IL      16415.0
# 930     Abingdon, IL      15711.0
#
# [1312 rows x 2 columns]

# %%
df_income_official2.iloc[930,:].city_name = 'Abingdon, IL'

# %%
df_income_official2.city_name.str.strip()
# Out:
# 0                  Winnetka
# 1                Kenilworth
# 2                   Glencoe
# 3                 Inverness
# 4          Barrington Hills
#                ...
# 1307    Washington Park, IL
# 1308         Mill Creek, IL
# 1309           Brooklyn, IL
# 1310           Fidelity, IL
# 1311        Valley City, IL
# Name: city_name, Length: 1312, dtype: object

# %%
df_income_official2["city_name"]=df_income_official2["city_name"].str.strip()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# # Let's merge two dataset
# * The dataset of population
# * The dataset of the income of each city

# %%
df_population_official.head()
# Out:
#       city_name population
# 0  Abingdon, IL      3,226
# 1     Adair, IL        210
# 2    Addieville        243
# 3   Addison, IL     37,297
# 4    Albany, IL        883

# %%
df_income_official2
# Out:
#                 city_name  city_income
# 0                Winnetka      98139.0
# 1              Kenilworth      97381.0
# 2                 Glencoe      94900.0
# 3               Inverness      91623.0
# 4        Barrington Hills      91555.0
# ...                   ...          ...
# 1307  Washington Park, IL       8495.0
# 1308       Mill Creek, IL       8317.0
# 1309         Brooklyn, IL       7944.0
# 1310         Fidelity, IL       7798.0
# 1311      Valley City, IL       6833.0
#
# [1312 rows x 2 columns]

# %%
df_income_population_merged = pd.merge(df_population_official, df_income_official2, how="inner", on="city_name")
df_income_population_merged
# Out:
#          city_name population  city_income
# 0     Abingdon, IL      3,226      15711.0
# 1      Addison, IL     37,297      21201.0
# 2       Albany, IL        883      18780.0
# 3       Albion, IL      1,957      14747.0
# 4        Aledo, IL      3,588      18498.0
# ..             ...        ...          ...
# 666      Worth, IL     10,838      19449.0
# 667    Wyoming, IL      1,383      16574.0
# 668      Xenia, IL        385      16944.0
# 669  Yorkville, IL     18,096      24514.0
# 670       Zion, IL     24,264      17730.0
#
# [671 rows x 3 columns]

# %%
df_income_population_merged.dtypes
# Out:
# city_name       object
# population      object
# city_income    float64
# dtype: object

# %%
df_income_population_merged.population=df_income_population_merged.population.apply(lambda x: convert_to_float(x))

# %%
df_income_population_merged.dtypes
# Out:
# city_name       object
# population     float64
# city_income    float64
# dtype: object

# %%
df_income_population_merged.isnull().sum()
# Out:
# city_name      0
# population     0
# city_income    0
# dtype: int64

# %% [markdown]
# ## Load our Dataset of The price of Houses of all state in USA

# %%
#load our dataset
df_city = pd.read_csv('Data/City_zhvi_uc_sfrcondo_tier_0.67_1.0_sm_sa_mon.csv')

# %%
# let's see the dataset of the city
df_city
# Out:
#        RegionID  SizeRank   RegionName RegionType StateName State  \
# 0          6181         0     New York       City        NY    NY
# 1         12447         1  Los Angeles       City        CA    CA
# 2         39051         2      Houston       City        TX    TX
# 3         17426         3      Chicago       City        IL    IL
# 4          6915         4  San Antonio       City        TX    TX
# ...         ...       ...          ...        ...       ...   ...
# 26814     31730     29449      Gerlach       City        NV    NV
# 26815     51148     29449    Broad Top       City        PA    PA
# 26816    232332     29449         Cool       City        TX    TX
# 26817      5133     29449    Hermitage       City        MO    MO
# 26818     11693     30967  Great Lakes       City        IL    IL
#
#                                   Metro          CountyName  1/31/1996  \
# 0           New York-Newark-Jersey City       Queens County   360437.0
# 1        Los Angeles-Long Beach-Anaheim  Los Angeles County   369516.0
# 2      Houston-The Woodlands-Sugar Land       Harris County   204412.0
# 3              Chicago-Naperville-Elgin         Cook County   253876.0
# 4             San Antonio-New Braunfels        Bexar County   161869.0
# ...                                 ...                 ...        ...
# 26814                              Reno       Washoe County        NaN
# 26815                        Huntingdon   Huntingdon County        NaN
# 26816       Dallas-Fort Worth-Arlington       Parker County        NaN
# 26817                               NaN      Hickory County        NaN
# 26818          Chicago-Naperville-Elgin         Cook County        NaN
#
#        2/29/1996  ...  9/30/2019  10/31/2019  11/30/2019  12/31/2019  \
# 0       359463.0  ...  1159081.0   1155710.0   1152952.0   1151860.0
# 1       369755.0  ...  1463186.0   1468688.0   1472616.0   1479035.0
# 2       204513.0  ...   374714.0    375528.0    375687.0    375953.0
# 3       253589.0  ...   463247.0    462900.0    462366.0    461987.0
# 4       161767.0  ...   286581.0    287299.0    288217.0    288262.0
# ...          ...  ...        ...         ...         ...         ...
# 26814        NaN  ...   354454.0    355034.0    357955.0    359513.0
# 26815        NaN  ...   186038.0    186477.0    186906.0    186853.0
# 26816        NaN  ...   393361.0    397951.0    403682.0    410258.0
# 26817        NaN  ...   159430.0    158711.0    157812.0    157621.0
# 26818        NaN  ...   269889.0    267881.0    266435.0    263386.0
#
#        1/31/2020  2/29/2020  3/31/2020  4/30/2020  5/31/2020  6/30/2020
# 0      1150843.0  1149625.0  1147147.0  1146988.0  1145703.0  1145768.0
# 1      1485192.0  1495670.0  1504868.0  1511249.0  1509761.0  1506431.0
# 2       375563.0   375973.0   377027.0   378328.0   379188.0   379639.0
# 3       462121.0   462767.0   463652.0   463953.0   464035.0   464325.0
# 4       288800.0   288802.0   289417.0   289523.0   289851.0   290157.0
# ...          ...        ...        ...        ...        ...        ...
# 26814   363635.0   365665.0   367447.0   370827.0   375827.0   380627.0
# 26815   186811.0   186526.0   187059.0   186684.0   186525.0   185683.0
# 26816   416727.0   421870.0   423341.0   425056.0   423859.0   421130.0
# 26817   156958.0   156677.0   156208.0   155720.0   154894.0   154366.0
# 26818   262537.0   262079.0   262129.0   260642.0   260536.0   261278.0
#
# [26819 rows x 302 columns]

# %% [markdown]
# # Filtre all IL (Illinois) in Data of houses Price

# %%
#trill the lines of city in the from column 'RegionType' and IL in the from column 'StateName'.
df_city_filtred = df_city[(df_city["RegionType"] == 'City')& (df_city["StateName"] == 'IL') ]
df_city_filtred
# Out:
#        RegionID  SizeRank    RegionName RegionType StateName State  \
# 3         17426         3       Chicago       City        IL    IL
# 143       10215       144        Aurora       City        IL    IL
# 156       47426       157      Rockford       City        IL    IL
# 190       39931       192    Naperville       City        IL    IL
# 279       54522       284   Springfield       City        IL    IL
# ...         ...       ...           ...        ...       ...   ...
# 26601     17406     29449      Chebanse       City        IL    IL
# 26618      4814     29449  Freeman Spur       City        IL    IL
# 26698    139108     29449    Lake Ka-ho       City        IL    IL
# 26772     45716     29449     Henderson       City        IL    IL
# 26818     11693     30967   Great Lakes       City        IL    IL
#
#                           Metro         CountyName  1/31/1996  2/29/1996  ...  \
# 3      Chicago-Naperville-Elgin        Cook County   253876.0   253589.0  ...
# 143    Chicago-Naperville-Elgin        Kane County   185173.0   185039.0  ...
# 156                    Rockford   Winnebago County   124834.0   124722.0  ...
# 190    Chicago-Naperville-Elgin      DuPage County   320455.0   320532.0  ...
# 279                 Springfield    Sangamon County        NaN        NaN  ...
# ...                         ...                ...        ...        ...  ...
# 26601                       NaN    Iroquois County        NaN        NaN  ...
# 26618         Carbondale-Marion  Williamson County        NaN        NaN  ...
# 26698                 St. Louis    Macoupin County        NaN        NaN  ...
# 26772                 Galesburg        Knox County        NaN        NaN  ...
# 26818  Chicago-Naperville-Elgin        Cook County        NaN        NaN  ...
#
#        9/30/2019  10/31/2019  11/30/2019  12/31/2019  1/31/2020  2/29/2020  \
# 3       463247.0    462900.0    462366.0    461987.0   462121.0   462767.0
# 143     283674.0    283272.0    283405.0    283468.0   283776.0   283589.0
# 156     155825.0    156069.0    156407.0    156595.0   156780.0   156682.0
# 190     538675.0    538591.0    538599.0    539199.0   540000.0   540545.0
# 279     218774.0    218988.0    219187.0    219269.0   219530.0   219857.0
# ...          ...         ...         ...         ...        ...        ...
# 26601   170794.0    171993.0    173741.0    175714.0   176570.0   177293.0
# 26618    68547.0     68441.0     68222.0     68313.0    68616.0    68666.0
# 26698    55155.0     55215.0     55382.0     55765.0    56260.0    56841.0
# 26772   126106.0    126166.0    126220.0    126267.0   126475.0   126690.0
# 26818   269889.0    267881.0    266435.0    263386.0   262537.0   262079.0
#
#        3/31/2020  4/30/2020  5/31/2020  6/30/2020
# 3       463652.0   463953.0   464035.0   464325.0
# 143     283913.0   284148.0   284302.0   284554.0
# 156     156543.0   156585.0   156714.0   157083.0
# 190     541031.0   540447.0   539459.0   538502.0
# 279     220172.0   220354.0   220617.0   221303.0
# ...          ...        ...        ...        ...
# 26601   177112.0   177393.0   177177.0   178883.0
# 26618    68033.0    67486.0    67377.0    67156.0
# 26698    57438.0    57713.0    57903.0    58058.0
# 26772   127084.0   127589.0   127879.0   128138.0
# 26818   262129.0   260642.0   260536.0   261278.0
#
# [1280 rows x 302 columns]

# %%
df_city_filtred.rename(columns = {'CountyName':'county_name'}, inplace = True)

# %%
df_city_filtred.head()
# Out:
#      RegionID  SizeRank   RegionName RegionType StateName State  \
# 3       17426         3      Chicago       City        IL    IL
# 143     10215       144       Aurora       City        IL    IL
# 156     47426       157     Rockford       City        IL    IL
# 190     39931       192   Naperville       City        IL    IL
# 279     54522       284  Springfield       City        IL    IL
#
#                         Metro       county_name  1/31/1996  2/29/1996  ...  \
# 3    Chicago-Naperville-Elgin       Cook County   253876.0   253589.0  ...
# 143  Chicago-Naperville-Elgin       Kane County   185173.0   185039.0  ...
# 156                  Rockford  Winnebago County   124834.0   124722.0  ...
# 190  Chicago-Naperville-Elgin     DuPage County   320455.0   320532.0  ...
# 279               Springfield   Sangamon County        NaN        NaN  ...
#
#      9/30/2019  10/31/2019  11/30/2019  12/31/2019  1/31/2020  2/29/2020  \
# 3     463247.0    462900.0    462366.0    461987.0   462121.0   462767.0
# 143   283674.0    283272.0    283405.0    283468.0   283776.0   283589.0
# 156   155825.0    156069.0    156407.0    156595.0   156780.0   156682.0
# 190   538675.0    538591.0    538599.0    539199.0   540000.0   540545.0
# 279   218774.0    218988.0    219187.0    219269.0   219530.0   219857.0
#
#      3/31/2020  4/30/2020  5/31/2020  6/30/2020
# 3     463652.0   463953.0   464035.0   464325.0
# 143   283913.0   284148.0   284302.0   284554.0
# 156   156543.0   156585.0   156714.0   157083.0
# 190   541031.0   540447.0   539459.0   538502.0
# 279   220172.0   220354.0   220617.0   221303.0
#
# [5 rows x 302 columns]

# %% [markdown]
# ## Load Dataset of Crime

# %%
df_crime = pd.read_csv('Data/2018_ucr_index_arrest-191115T22305341.csv')

# %%
# 
df_crime.head()
# Out:
#    year  id  fips_number       county_name judicial_circuit            region  \
# 0  1982   1            1      Adams County                8           Central
# 1  1982   2            3  Alexander County                1          Southern
# 2  1982   3            5       Bond County                3          Southern
# 3  1982   4            7      Boone County               17  Northern - Other
# 4  1982   5            9      Brown County                8           Central
#
#   community_type  percent_rural  population  aggravated_assault  ...  robbery  \
# 0   Mostly Urban           32.6       71174                45.0  ...      6.0
# 1   Mostly Rural           61.9       12056                75.0  ...     10.0
# 2   Mostly Rural           60.7       16132                 0.0  ...      0.0
# 3   Mostly Urban           19.4       29213                 7.0  ...      0.0
# 4   Mostly Urban           41.1        5588                 0.0  ...      0.0
#
#    sexual_assault  aggravated_assault_rate  arson_rate  burglary_rate  \
# 0             5.0                     63.2         5.6           75.9
# 1             2.0                    622.1         0.0          265.4
# 2             0.0                      0.0         0.0           12.4
# 3             0.0                     24.0         0.0          140.3
# 4             0.0                      0.0         0.0           71.6
#
#    larceny_theft_rate  motor_vehicle_theft_rate  murder_rate  robbery_rate  \
# 0               458.0                      11.2          4.2           8.4
# 1               472.8                      16.6          8.3          82.9
# 2               117.8                      18.6          0.0           0.0
# 3               349.2                      17.1          0.0           0.0
# 4               161.1                       0.0          0.0           0.0
#
#    sexual_assault_rate
# 0                  7.0
# 1                 16.6
# 2                  0.0
# 3                  0.0
# 4                  0.0
#
# [5 rows x 25 columns]

# %%
df_crime.dtypes
# Out:
# year                          int64
# id                            int64
# fips_number                   int64
# county_name                  object
# judicial_circuit             object
# region                       object
# community_type               object
# percent_rural               float64
# population                    int64
# aggravated_assault          float64
# arson                       float64
# burglary                    float64
# larceny_theft               float64
# motor_vehicle_theft         float64
# murder                      float64
# robbery                     float64
# sexual_assault              float64
# aggravated_assault_rate     float64
# arson_rate                  float64
# burglary_rate               float64
# larceny_theft_rate          float64
# motor_vehicle_theft_rate    float64
# murder_rate                 float64
# robbery_rate                float64
# sexual_assault_rate         float64
# dtype: object

# %%
df_crime.describe()
# Out:
#               year          id  fips_number  percent_rural    population  \
# count  3774.000000  3774.00000    3774.0000    3774.000000  3.774000e+03
# mean   2000.000000    51.50000     102.0000      51.091176  1.199998e+05
# std      10.678493    29.44735      58.8947      27.843314  5.261292e+05
# min    1982.000000     1.00000       1.0000       0.000000  3.910000e+03
# 25%    1991.000000    26.00000      51.0000      31.300000  1.482700e+04
# 50%    2000.000000    51.50000     102.0000      50.400000  2.659100e+04
# 75%    2009.000000    77.00000     153.0000      69.900000  5.376275e+04
# max    2018.000000   102.00000     203.0000     100.000000  5.376861e+06
#
#        aggravated_assault        arson      burglary  larceny_theft  \
# count         3751.000000  3751.000000   3751.000000    3751.000000
# mean           154.591576     5.387097    115.155425     659.810184
# std            747.592803    27.283646    625.322925    3981.516315
# min              0.000000     0.000000      0.000000       0.000000
# 25%             10.000000     0.000000      8.000000      19.000000
# 50%             28.000000     1.000000     20.000000      55.000000
# 75%             81.000000     3.000000     56.000000     228.500000
# max          12720.000000   423.000000  10569.000000   58085.000000
#
#        motor_vehicle_theft  ...      robbery  sexual_assault  \
# count          3751.000000  ...  3751.000000     3751.000000
# mean             75.676620  ...    51.546521       15.161024
# std             702.587624  ...   414.992331       82.803219
# min               0.000000  ...     0.000000        0.000000
# 25%               1.000000  ...     0.000000        0.000000
# 50%               4.000000  ...     1.000000        2.000000
# 75%              10.000000  ...     6.000000        8.000000
# max           12084.000000  ...  6567.000000     1350.000000
#
#        aggravated_assault_rate   arson_rate  burglary_rate  \
# count              3751.000000  3751.000000    3751.000000
# mean                134.175207     4.061717      88.581098
# std                 124.082830     6.463609      71.117795
# min                   0.000000     0.000000       0.000000
# 25%                  50.000000     0.000000      40.700000
# 50%                 100.100000     1.900000      73.200000
# 75%                 182.250000     5.900000     118.050000
# max                1353.800000    74.000000     883.200000
#
#        larceny_theft_rate  motor_vehicle_theft_rate  murder_rate  \
# count         3751.000000               3751.000000  3751.000000
# mean           290.232871                 17.821034     2.096134
# std            221.923599                 20.865608     4.501034
# min              0.000000                  0.000000     0.000000
# 25%            121.750000                  5.200000     0.000000
# 50%            235.000000                 13.200000     0.000000
# 75%            413.700000                 23.400000     2.800000
# max           1592.600000                225.200000    78.800000
#
#        robbery_rate  sexual_assault_rate
# count   3751.000000          3751.000000
# mean      10.247961            11.462063
# std       16.917972            14.126756
# min        0.000000             0.000000
# 25%        0.000000             0.000000
# 50%        3.300000             7.600000
# 75%       13.700000            16.000000
# max      247.900000           189.500000
#
# [8 rows x 21 columns]

# %%
#add 'County' in our dataset of the column of county_name
df_crime.county_name = df_crime.county_name + str(' County')

# %%
df_crime
# Out:
#       year   id  fips_number        county_name judicial_circuit  \
# 0     1982    1            1       Adams County                8
# 1     1982    2            3   Alexander County                1
# 2     1982    3            5        Bond County                3
# 3     1982    4            7       Boone County               17
# 4     1982    5            9       Brown County                8
# ...    ...  ...          ...                ...              ...
# 3769  2018   98          195   Whiteside County               14
# 3770  2018   99          197        Will County               12
# 3771  2018  100          199  Williamson County                1
# 3772  2018  101          201   Winnebago County               17
# 3773  2018  102          203    Woodford County               11
#
#                  region community_type  percent_rural  population  \
# 0               Central   Mostly Urban           32.6       71174
# 1              Southern   Mostly Rural           61.9       12056
# 2              Southern   Mostly Rural           60.7       16132
# 3      Northern - Other   Mostly Urban           19.4       29213
# 4               Central   Mostly Urban           41.1        5588
# ...                 ...            ...            ...         ...
# 3769   Northern - Other   Mostly Urban           37.3       55626
# 3770  Northern - Collar   Mostly Urban            3.9      692310
# 3771           Southern   Mostly Urban           34.8       67056
# 3772   Northern - Other   Mostly Urban            7.9      284081
# 3773            Central   Mostly Rural           54.9       38463
#
#       aggravated_assault  ...  robbery  sexual_assault  \
# 0                   45.0  ...      6.0             5.0
# 1                   75.0  ...     10.0             2.0
# 2                    0.0  ...      0.0             0.0
# 3                    7.0  ...      0.0             0.0
# 4                    0.0  ...      0.0             0.0
# ...                  ...  ...      ...             ...
# 3769                37.0  ...      4.0             3.0
# 3770               411.0  ...     53.0            24.0
# 3771                13.0  ...      0.0             1.0
# 3772               548.0  ...     94.0            28.0
# 3773                11.0  ...      0.0             1.0
#
#       aggravated_assault_rate  arson_rate  burglary_rate  larceny_theft_rate  \
# 0                        63.2         5.6           75.9               458.0
# 1                       622.1         0.0          265.4               472.8
# 2                         0.0         0.0           12.4               117.8
# 3                        24.0         0.0          140.3               349.2
# 4                         0.0         0.0           71.6               161.1
# ...                       ...         ...            ...                 ...
# 3769                     66.5         0.0           39.5               102.5
# 3770                     59.4         0.9           13.1               159.8
# 3771                     19.4         0.0           10.4                59.7
# 3772                    192.9         6.7           46.8               340.7
# 3773                     28.6         0.0            2.6                28.6
#
#       motor_vehicle_theft_rate  murder_rate  robbery_rate  sexual_assault_rate
# 0                         11.2          4.2           8.4                  7.0
# 1                         16.6          8.3          82.9                 16.6
# 2                         18.6          0.0           0.0                  0.0
# 3                         17.1          0.0           0.0                  0.0
# 4                          0.0          0.0           0.0                  0.0
# ...                        ...          ...           ...                  ...
# 3769                      14.4          0.0           7.2                  5.4
# 3770                       5.2          1.3           7.7                  3.5
# 3771                       1.5          0.0           0.0                  1.5
# 3772                       8.1          7.4          33.1                  9.9
# 3773                       7.8          0.0           0.0                  2.6
#
# [3774 rows x 25 columns]

# %% [markdown]
# ## Let's Merge two dataset:
# * The Dataset of Crime in Illinois (IL)
# * The Dataset of City

# %%
#Let's Merge two dataset Crime and the City
df_city_crime_merge = pd.merge(df_city_filtred, df_crime, how="inner", on="county_name")
df_city_crime_merge
# Out:
#        RegionID  SizeRank RegionName RegionType StateName State  \
# 0         17426         3    Chicago       City        IL    IL
# 1         17426         3    Chicago       City        IL    IL
# 2         17426         3    Chicago       City        IL    IL
# 3         17426         3    Chicago       City        IL    IL
# 4         17426         3    Chicago       City        IL    IL
# ...         ...       ...        ...        ...       ...   ...
# 45209     32015     23495      Herod       City        IL    IL
# 45210     32015     23495      Herod       City        IL    IL
# 45211     32015     23495      Herod       City        IL    IL
# 45212     32015     23495      Herod       City        IL    IL
# 45213     32015     23495      Herod       City        IL    IL
#
#                           Metro    county_name  1/31/1996  2/29/1996  ...  \
# 0      Chicago-Naperville-Elgin    Cook County   253876.0   253589.0  ...
# 1      Chicago-Naperville-Elgin    Cook County   253876.0   253589.0  ...
# 2      Chicago-Naperville-Elgin    Cook County   253876.0   253589.0  ...
# 3      Chicago-Naperville-Elgin    Cook County   253876.0   253589.0  ...
# 4      Chicago-Naperville-Elgin    Cook County   253876.0   253589.0  ...
# ...                         ...            ...        ...        ...  ...
# 45209                       NaN  Hardin County        NaN        NaN  ...
# 45210                       NaN  Hardin County        NaN        NaN  ...
# 45211                       NaN  Hardin County        NaN        NaN  ...
# 45212                       NaN  Hardin County        NaN        NaN  ...
# 45213                       NaN  Hardin County        NaN        NaN  ...
#
#        robbery  sexual_assault  aggravated_assault_rate  arson_rate  \
# 0       6567.0           870.0                     51.7         7.5
# 1       6029.0           807.0                     45.2         7.7
# 2       5520.0          1012.0                    153.4         7.4
# 3       4680.0          1350.0                    143.2         7.6
# 4       4573.0          1254.0                    134.0         6.7
# ...        ...             ...                      ...         ...
# 45209      0.0             0.0                    120.5         0.0
# 45210      0.0             1.0                     98.4         0.0
# 45211      0.0             0.0                    100.3         0.0
# 45212      2.0             0.0                    457.4        50.8
# 45213      0.0             0.0                    153.5         0.0
#
#        burglary_rate  larceny_theft_rate  motor_vehicle_theft_rate  \
# 0              197.8               954.1                      79.3
# 1              202.7               986.5                      80.7
# 2              181.3              1009.2                      77.4
# 3              166.1               974.6                      78.7
# 4              174.3               951.3                      91.5
# ...              ...                 ...                       ...
# 45209           48.2               458.1                       0.0
# 45210           49.2               196.8                      24.6
# 45211           25.1               275.8                     100.3
# 45212           50.8                76.2                      76.2
# 45213           25.6               102.3                      51.2
#
#        murder_rate  robbery_rate  sexual_assault_rate
# 0             20.5         125.7                 16.7
# 1             18.1         115.6                 15.5
# 2             19.2         105.7                 19.4
# 3             16.7          90.0                 26.0
# 4             16.2          88.2                 24.2
# ...            ...           ...                  ...
# 45209          0.0           0.0                  0.0
# 45210          0.0           0.0                 24.6
# 45211          0.0           0.0                  0.0
# 45212         25.4          50.8                  0.0
# 45213          0.0           0.0                  0.0
#
# [45214 rows x 326 columns]

# %% [markdown]
# # See the average prices in the equation and their variation in the date columns????

# %% [markdown]
# ## Methodology <a name="methodology"></a>
#
#
# The City of Chicago, is the most populous city in the U.S. state of Illinois, and the third-most-populous city in the United States. With an estimated population of 2,693,976 in 2019, it is also the most populous city in the Midwestern United States.
#
# Our job is to help someone moving to Chicago to find a house in a safe area so that they are comfortable and at an adequate price after getting information about the wages of people living in Chicago.
#
# * For our work we did the web scrapping to extract data needed for our Analysis.
# * Recommend him what salary he could get living in Chicago depending on the town.
# * We would like to have some data found in foursquare so we can see some closer to home such as (church, school, restaurant,     movie theater, super market...)
# * We would like to establish a linear regression on the prices of the houses.
# * Make a prediction to see how they'll change in a few years.
# * Show him the venues (church, school, restaurant, cinema, supermarket...) near his home via a map.
#
# Since our dataset contains the house prices per month from 1996 to 2020, we will filter the columns of the last two years from 2018 to 2020.
#
# * Remove missing values.
# * Count how many homes sold in each area.
# * Count how many homes per month and year.
